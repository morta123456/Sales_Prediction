# %% [markdown]
# <center><h1>Sales Prediction</h1></center>
#     <img src = "https://ierp.ai/wp-content/uploads/2021/01/Sales-Forecast-Blog.png">

# %% [markdown]
# Table of contents:
#
# 1. [Import relevant libraries](#Libraries)
# 2. [Load files](#Load)
# 3. [Data Exploration](#Exploration)
# 4. [Data Cleaning](#Cleaning)
# 5. [EDA(Exploratory Data Analysis)](#EDA)
# 6. [Preprocessing Data](#Cleaning)
# 7. [Correlations & Distributions ](#Correlations)
# 8. [Splitting the Data](#Splitting)
# 9. [Model training](#Model)
# 10. [Test set predictions](#Predictions)

# %% [markdown]
# <a name = "Libraries"></a>
# ## 1. Import relevant libraries

# %%
# Install xgboost
# !pip install xgboost
# !pip install imbalanced-learn
# !pip install ipywidgets
# !jupyter nbextension enable --py widgetsnbextension

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns 
import time

from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import tree
from scipy import stats
from ipywidgets import IntProgress, HTML, VBox
import ipywidgets as widgets
from IPython.display import display
from tqdm import tqdm
from tqdm.auto import tqdm

from sklearn.preprocessing import StandardScaler,OrdinalEncoder,LabelEncoder,MinMaxScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score ,KFold
from xgboost import plot_importance

pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')

sns.set_style("darkgrid")

# %% [markdown]
# <a name = "Load"></a>
# ## 2. Load files

# %%
#Loading dataset
df = pd.read_excel('newdata.xlsx')
df.describe().T.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_1758e_row0_col0, #T_1758e_row2_col0, #T_1758e_row3_col0, #T_1758e_row4_col0, #T_1758e_row5_col0, #T_1758e_row6_col0, #T_1758e_row6_col2, #T_1758e_row7_col0, #T_1758e_row8_col0, #T_1758e_row8_col7, #T_1758e_row9_col0, #T_1758e_row9_col1, #T_1758e_row9_col3, #T_1758e_row9_col4, #T_1758e_row9_col5, #T_1758e_row9_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_1758e_row0_col1, #T_1758e_row0_col2, #T_1758e_row0_col3, #T_1758e_row0_col4, #T_1758e_row0_col5, #T_1758e_row0_col6, #T_1758e_row0_col7, #T_1758e_row1_col0, #T_1758e_row1_col3, #T_1758e_row3_col1, #T_1758e_row3_col2, #T_1758e_row3_col3, #T_1758e_row3_col4, #T_1758e_row3_col5, #T_1758e_row3_col6, #T_1758e_row3_col7, #T_1758e_row4_col1, #T_1758e_row4_col2, #T_1758e_row4_col3, #T_1758e_row4_col4, #T_1758e_row4_col5, #T_1758e_row4_col6, #T_1758e_row4_col7, #T_1758e_row5_col3, #T_1758e_row5_col4, #T_1758e_row5_col5, #T_1758e_row7_col3, #T_1758e_row8_col3, #T_1758e_row9_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_1758e_row1_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_1758e_row1_col2, #T_1758e_row1_col6 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_1758e_row1_col4, #T_1758e_row1_col7 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_1758e_row1_col5 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_1758e_row2_col1, #T_1758e_row2_col5 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_1758e_row2_col2 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_1758e_row2_col3, #T_1758e_row6_col3 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_1758e_row2_col4 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_1758e_row2_col6 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_1758e_row2_col7 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_1758e_row5_col1, #T_1758e_row5_col6 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_1758e_row5_col2 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_1758e_row5_col7, #T_1758e_row6_col4 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_1758e_row6_col1 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_1758e_row6_col5 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_1758e_row6_col6 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_1758e_row6_col7 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_1758e_row7_col1 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_1758e_row7_col2 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_1758e_row7_col4 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_1758e_row7_col5 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_1758e_row7_col6 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_1758e_row7_col7 {
#   background-color: #016e2d;
#   color: #f1f1f1;
# }
# #T_1758e_row8_col1 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_1758e_row8_col2 {
#   background-color: #005a24;
#   color: #f1f1f1;
# }
# #T_1758e_row8_col4 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_1758e_row8_col5 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_1758e_row8_col6 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_1758e_row9_col7 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# </style>
# <table id="T_1758e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1758e_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_1758e_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_1758e_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_1758e_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_1758e_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_1758e_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_1758e_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_1758e_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1758e_level0_row0" class="row_heading level0 row0" >id_segment</th>
#       <td id="T_1758e_row0_col0" class="data row0 col0" >51318.000000</td>
#       <td id="T_1758e_row0_col1" class="data row0 col1" >1.783838</td>
#       <td id="T_1758e_row0_col2" class="data row0 col2" >0.878129</td>
#       <td id="T_1758e_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_1758e_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_1758e_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_1758e_row0_col6" class="data row0 col6" >3.000000</td>
#       <td id="T_1758e_row0_col7" class="data row0 col7" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1758e_level0_row1" class="row_heading level0 row1" >id_state</th>
#       <td id="T_1758e_row1_col0" class="data row1 col0" >5824.000000</td>
#       <td id="T_1758e_row1_col1" class="data row1 col1" >87.396806</td>
#       <td id="T_1758e_row1_col2" class="data row1 col2" >45.506065</td>
#       <td id="T_1758e_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_1758e_row1_col4" class="data row1 col4" >49.000000</td>
#       <td id="T_1758e_row1_col5" class="data row1 col5" >97.000000</td>
#       <td id="T_1758e_row1_col6" class="data row1 col6" >121.000000</td>
#       <td id="T_1758e_row1_col7" class="data row1 col7" >175.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1758e_level0_row2" class="row_heading level0 row2" >Unit Price</th>
#       <td id="T_1758e_row2_col0" class="data row2 col0" >51318.000000</td>
#       <td id="T_1758e_row2_col1" class="data row2 col1" >237.682314</td>
#       <td id="T_1758e_row2_col2" class="data row2 col2" >126.278644</td>
#       <td id="T_1758e_row2_col3" class="data row2 col3" >19.000000</td>
#       <td id="T_1758e_row2_col4" class="data row2 col4" >128.000000</td>
#       <td id="T_1758e_row2_col5" class="data row2 col5" >238.000000</td>
#       <td id="T_1758e_row2_col6" class="data row2 col6" >347.000000</td>
#       <td id="T_1758e_row2_col7" class="data row2 col7" >457.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1758e_level0_row3" class="row_heading level0 row3" >quantity</th>
#       <td id="T_1758e_row3_col0" class="data row3 col0" >51318.000000</td>
#       <td id="T_1758e_row3_col1" class="data row3 col1" >3.476071</td>
#       <td id="T_1758e_row3_col2" class="data row3 col2" >2.278623</td>
#       <td id="T_1758e_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_1758e_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_1758e_row3_col5" class="data row3 col5" >3.000000</td>
#       <td id="T_1758e_row3_col6" class="data row3 col6" >5.000000</td>
#       <td id="T_1758e_row3_col7" class="data row3 col7" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1758e_level0_row4" class="row_heading level0 row4" >discount</th>
#       <td id="T_1758e_row4_col0" class="data row4 col0" >51318.000000</td>
#       <td id="T_1758e_row4_col1" class="data row4 col1" >0.142907</td>
#       <td id="T_1758e_row4_col2" class="data row4 col2" >0.212283</td>
#       <td id="T_1758e_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_1758e_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_1758e_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_1758e_row4_col6" class="data row4 col6" >0.200000</td>
#       <td id="T_1758e_row4_col7" class="data row4 col7" >0.850000</td>
#     </tr>
#     <tr>
#       <th id="T_1758e_level0_row5" class="row_heading level0 row5" >shipping_cost</th>
#       <td id="T_1758e_row5_col0" class="data row5 col0" >51318.000000</td>
#       <td id="T_1758e_row5_col1" class="data row5 col1" >26.365946</td>
#       <td id="T_1758e_row5_col2" class="data row5 col2" >57.284882</td>
#       <td id="T_1758e_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_1758e_row5_col4" class="data row5 col4" >2.610000</td>
#       <td id="T_1758e_row5_col5" class="data row5 col5" >7.790000</td>
#       <td id="T_1758e_row5_col6" class="data row5 col6" >24.440000</td>
#       <td id="T_1758e_row5_col7" class="data row5 col7" >933.570000</td>
#     </tr>
#     <tr>

# %%
data = pd.DataFrame(df)

# %%
data.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0  ES-2011-1630549 2011-04-16 2011-04-21  Standard Class    Dianna Wilson
# 1   MX-2013-132906 2012-05-25 2012-05-30  Standard Class        Denny Joy
# 2   MX-2013-113579 2012-07-13 2012-07-17  Standard Class  Arthur Wiediger
# 3   CA-2013-116337 2012-09-04 2012-09-08  Standard Class      Dean Braden
# 4  ES-2013-4232414 2012-09-04 2012-09-08  Standard Class      Dean Braden
#
#    id_segment      segment  id_state state  country  market  region  \
# 0           2  Home Office       1.0  Abia  Nigeria  Africa  Africa
# 1           3    Corporate       1.0  Abia  Nigeria  Africa  Africa
# 2           2  Home Office       1.0  Abia  Nigeria  Africa  Africa
# 3           1     Consumer       1.0  Abia  Nigeria  Africa  Africa
# 4           1     Consumer       1.0  Abia  Nigeria  Africa  Africa
#
#          product_id         category sub_category             product_name  \
# 0  OFF-BOS-10001348  OFFICE SUPPLIES          ART  Boston Pencil Sharpener
# 1  OFF-FIS-10001797  OFFICE SUPPLIES     SUPPLIES          Fiskars Trimmer
# 2  OFF-SME-10001718  OFFICE SUPPLIES      STORAGE                Smead Box
# 3  OFF-SME-10001718  OFFICE SUPPLIES      STORAGE                Smead Box
# 4  OFF-BIN-10004512  OFFICE SUPPLIES          ART      Binney & Smith Pens
#
#   product_name.1 product_name.2 product_name.3 product_name.4 product_name.5  \
# 0    Water Color            NaN            NaN            NaN            NaN
# 1          Steel            NaN            NaN            NaN            NaN
# 2     Industrial            NaN            NaN            NaN            NaN
# 3     Industrial            NaN            NaN            NaN            NaN
# 4     Easy-Erase            NaN            NaN            NaN            NaN
#
#    Unit Price  quantity  discount  shipping_cost order_priority  sales  \
# 0         117        14       0.7          10.61         Medium   1638
# 1         274         1       0.7           0.20         Medium    274
# 2         439         1       0.7           0.26         Medium    439
# 3          28         2       0.7           0.58         Medium     56
# 4         344         2       0.7           0.41         Medium    688
#
#    expenses  revenue   year
# 0  436.7487    502.01  2011
# 1   71.6880     82.40  2012
# 2  114.8052    131.96  2012
# 3   15.1206     17.38  2012
# 4  179.9247    206.81  2012

# %% [markdown]
# <a name = "Exploration"></a>
# ## 3. Data Exploration

# %%
data.set_index("order_id",inplace=True)
data.head()
# Out:
#                 order_date  ship_date       ship_mode    customer_name  \
# order_id
# ES-2011-1630549 2011-04-16 2011-04-21  Standard Class    Dianna Wilson
# MX-2013-132906  2012-05-25 2012-05-30  Standard Class        Denny Joy
# MX-2013-113579  2012-07-13 2012-07-17  Standard Class  Arthur Wiediger
# CA-2013-116337  2012-09-04 2012-09-08  Standard Class      Dean Braden
# ES-2013-4232414 2012-09-04 2012-09-08  Standard Class      Dean Braden
#
#                  id_segment      segment  id_state state  country  market  \
# order_id
# ES-2011-1630549           2  Home Office       1.0  Abia  Nigeria  Africa
# MX-2013-132906            3    Corporate       1.0  Abia  Nigeria  Africa
# MX-2013-113579            2  Home Office       1.0  Abia  Nigeria  Africa
# CA-2013-116337            1     Consumer       1.0  Abia  Nigeria  Africa
# ES-2013-4232414           1     Consumer       1.0  Abia  Nigeria  Africa
#
#                  region        product_id         category sub_category  \
# order_id
# ES-2011-1630549  Africa  OFF-BOS-10001348  OFFICE SUPPLIES          ART
# MX-2013-132906   Africa  OFF-FIS-10001797  OFFICE SUPPLIES     SUPPLIES
# MX-2013-113579   Africa  OFF-SME-10001718  OFFICE SUPPLIES      STORAGE
# CA-2013-116337   Africa  OFF-SME-10001718  OFFICE SUPPLIES      STORAGE
# ES-2013-4232414  Africa  OFF-BIN-10004512  OFFICE SUPPLIES          ART
#
#                             product_name product_name.1 product_name.2  \
# order_id
# ES-2011-1630549  Boston Pencil Sharpener    Water Color            NaN
# MX-2013-132906           Fiskars Trimmer          Steel            NaN
# MX-2013-113579                 Smead Box     Industrial            NaN
# CA-2013-116337                 Smead Box     Industrial            NaN
# ES-2013-4232414      Binney & Smith Pens     Easy-Erase            NaN
#
#                 product_name.3 product_name.4 product_name.5  Unit Price  \
# order_id
# ES-2011-1630549            NaN            NaN            NaN         117
# MX-2013-132906             NaN            NaN            NaN         274
# MX-2013-113579             NaN            NaN            NaN         439
# CA-2013-116337             NaN            NaN            NaN          28
# ES-2013-4232414            NaN            NaN            NaN         344
#
#                  quantity  discount  shipping_cost order_priority  sales  \
# order_id
# ES-2011-1630549        14       0.7          10.61         Medium   1638
# MX-2013-132906          1       0.7           0.20         Medium    274
# MX-2013-113579          1       0.7           0.26         Medium    439
# CA-2013-116337          2       0.7           0.58         Medium     56
# ES-2013-4232414         2       0.7           0.41         Medium    688
#
#                  expenses  revenue   year
# order_id
# ES-2011-1630549  436.7487    502.01  2011
# MX-2013-132906    71.6880     82.40  2012
# MX-2013-113579   114.8052    131.96  2012
# CA-2013-116337    15.1206     17.38  2012
# ES-2013-4232414  179.9247    206.81  2012

# %%
data.describe()
# Out:
#          id_segment     id_state    Unit Price      quantity      discount  \
# count  51318.000000  5824.000000  51318.000000  51318.000000  51318.000000
# mean       1.783838    87.396806    237.682314      3.476071      0.142907
# std        0.878129    45.506065    126.278644      2.278623      0.212283
# min        1.000000     1.000000     19.000000      1.000000      0.000000
# 25%        1.000000    49.000000    128.000000      2.000000      0.000000
# 50%        1.000000    97.000000    238.000000      3.000000      0.000000
# 75%        3.000000   121.000000    347.000000      5.000000      0.200000
# max        3.000000   175.000000    457.000000     14.000000      0.850000
#
#        shipping_cost         sales      expenses      revenue           year
# count   51318.000000  51318.000000  51318.000000  51318.000000  51318.000000
# mean       26.365946    826.174305    641.180059    736.988574   2012.778713
# std        57.284882    752.664627    609.041486    700.047685      1.149308
# min         0.000000     19.000000      4.489200      5.160000   2001.000000
# 25%         2.610000    296.000000    217.439100    249.930000   2012.000000
# 50%         7.790000    604.000000    448.367550    515.365000   2013.000000
# 75%        24.440000   1125.000000    855.949500    983.850000   2014.000000
# max       933.570000   6398.000000   5597.049300   6433.390000   2088.000000

# %% [markdown]
# <a name = "Cleaning"></a>
# ## 4. Data Cleaning

# %% [markdown]
# ### Handeling Duplications

# %%
data.duplicated().value_counts()
# Out:
# False    51296
# True        22
# dtype: int64

# %%
# Removing duplications
duplicated_mask = data.duplicated()
data = data[~duplicated_mask]

# %%
data.duplicated().any()
# Out:
# False

# %%
data
# Out:
#                 order_date  ship_date       ship_mode    customer_name  \
# order_id
# ES-2011-1630549 2011-04-16 2011-04-21  Standard Class    Dianna Wilson
# MX-2013-132906  2012-05-25 2012-05-30  Standard Class        Denny Joy
# MX-2013-113579  2012-07-13 2012-07-17  Standard Class  Arthur Wiediger
# CA-2013-116337  2012-09-04 2012-09-08  Standard Class      Dean Braden
# ES-2013-4232414 2012-09-04 2012-09-08  Standard Class      Dean Braden
# ...                    ...        ...             ...              ...
# SU-2014-3390    2014-08-12 2014-08-19  Standard Class      Cathy Hwang
# EZ-2014-8670    2014-10-13 2014-10-17  Standard Class       Tony Sayre
# MO-2014-6030    2014-10-13 2014-10-17  Standard Class       Tony Sayre
# MX-2014-167493  2014-12-04 2014-12-11  Standard Class  Maria Bertelson
# IN-2011-71242   2013-09-10 2013-09-15    Second Class   Anne McFarland
#
#                  id_segment      segment  id_state   state        country  \
# order_id
# ES-2011-1630549           2  Home Office       1.0    Abia        Nigeria
# MX-2013-132906            3    Corporate       1.0    Abia        Nigeria
# MX-2013-113579            2  Home Office       1.0    Abia        Nigeria
# CA-2013-116337            1     Consumer       1.0    Abia        Nigeria
# ES-2013-4232414           1     Consumer       1.0    Abia        Nigeria
# ...                     ...          ...       ...     ...            ...
# SU-2014-3390              2  Home Office       NaN  Zürich          Italy
# EZ-2014-8670              1     Consumer       NaN  Zürich        Germany
# MO-2014-6030              1     Consumer       NaN  Zürich      Australia
# MX-2014-167493            1     Consumer       NaN  Zürich      Argentina
# IN-2011-71242             1     Consumer       NaN  Zürich  United States
#
#                  market   region        product_id         category  \
# order_id
# ES-2011-1630549  Africa   Africa  OFF-BOS-10001348  OFFICE SUPPLIES
# MX-2013-132906   Africa   Africa  OFF-FIS-10001797  OFFICE SUPPLIES
# MX-2013-113579   Africa   Africa  OFF-SME-10001718  OFFICE SUPPLIES
# CA-2013-116337   Africa   Africa  OFF-SME-10001718  OFFICE SUPPLIES
# ES-2013-4232414  Africa   Africa  OFF-BIN-10004512  OFFICE SUPPLIES
# ...                 ...      ...               ...              ...
# SU-2014-3390         EU    South   TEC-PH-10003713       TECHNOLOGY
# EZ-2014-8670         EU  Central   OFF-SU-10000906  OFFICE SUPPLIES
# MO-2014-6030       APAC  Oceania   OFF-PA-10003744  OFFICE SUPPLIES
# MX-2014-167493    LATAM    South   OFF-BI-10004145  OFFICE SUPPLIES
# IN-2011-71242        US     East   FUR-BO-10003660        FURNITURE
#
#                 sub_category                      product_name  \
# order_id
# ES-2011-1630549          ART           Boston Pencil Sharpener
# MX-2013-132906      SUPPLIES                   Fiskars Trimmer
# MX-2013-113579       STORAGE                         Smead Box
# CA-2013-116337       STORAGE                         Smead Box
# ES-2013-4232414          ART               Binney & Smith Pens
# ...                      ...                               ...
# SU-2014-3390          PHONES                  Cisco Audio Dock
# EZ-2014-8670        SUPPLIES                    Fiskars Shears
# MO-2014-6030           PAPER         Green Bar Parchment Paper
# MX-2014-167493       BINDERS  Wilson Jones Hole Reinforcements
# IN-2011-71242      BOOKCASES   Bush Cubix Collection Bookcases
#
#                    product_name.1 product_name.2 product_name.3  \
# order_id
# ES-2011-1630549       Water Color            NaN            NaN
# MX-2013-132906              Steel            NaN            NaN
# MX-2013-113579         Industrial            NaN            NaN
# CA-2013-116337         Industrial            NaN            NaN
# ES-2013-4232414        Easy-Erase            NaN            NaN
# ...                           ...            ...            ...
# SU-2014-3390             Cordless            NaN            NaN
# EZ-2014-8670           High Speed            NaN            NaN
# MO-2014-6030           Multicolor            NaN            NaN
# MX-2014-167493            Economy            NaN            NaN
# IN-2011-71242     Fully Assembled            NaN            NaN
#
#                 product_name.4 product_name.5  Unit Price  quantity  discount  \
# order_id
# ES-2011-1630549            NaN            NaN         117        14       0.7
# MX-2013-132906             NaN            NaN         274         1       0.7
# MX-2013-113579             NaN            NaN         439         1       0.7
# CA-2013-116337             NaN            NaN          28         2       0.7
# ES-2013-4232414            NaN            NaN         344         2       0.7
# ...                        ...            ...         ...       ...       ...
# SU-2014-3390               NaN            NaN         293         4       0.4
# EZ-2014-8670               NaN            NaN         315         6       0.0
# MO-2014-6030               NaN            NaN         419         4       0.1
# MX-2014-167493             NaN            NaN          60         4       0.7
# IN-2011-71242              NaN            NaN         353         1       0.0
#
#                  shipping_cost order_priority  sales   expenses  revenue   \
# order_id
# ES-2011-1630549          10.61         Medium   1638   436.7487    502.01
# MX-2013-132906            0.20         Medium    274    71.6880     82.40
# MX-2013-113579            0.26         Medium    439   114.8052    131.96
# CA-2013-116337            0.58         Medium     56    15.1206     17.38
# ES-2013-4232414           0.41         Medium    688   179.9247    206.81
# ...                        ...            ...    ...        ...       ...
# SU-2014-3390             32.70            Low   1172   640.2330    735.90
# EZ-2014-8670             21.16       Critical   1890  1662.7092   1911.16
# MO-2014-6030              9.61           High   1676  1320.6687   1518.01
# MX-2014-167493            0.24         Medium    240    62.8488     72.24
# IN-2011-71242            12.61         Medium    353   318.0807    365.61
#
#                  year
# order_id
# ES-2011-1630549  2011
# MX-2013-132906   2012
# MX-2013-113579   2012
# CA-2013-116337   2012
# ES-2013-4232414  2012
# ...               ...
# SU-2014-3390     2014
# EZ-2014-8670     2014
# MO-2014-6030     2014
# MX-2014-167493   2014
# IN-2011-71242    2014
#
# [51296 rows x 29 columns]

# %% [markdown]
# ### Handeling missing data

# %%
# Plot missing values in train set
ax = data.isna().sum().sort_values(ascending = False)[:8][::-1].plot(kind = 'barh', figsize = (9, 10))
plt.title('Percentage of Missing Values Per Column in Train Set', fontdict={'size':15})
for p in ax.patches:
    percentage ='{:,.0f}%'.format((p.get_width()/data.shape[0])*100)
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y))

# %%
data = data.drop(['product_name.1','product_name.2','product_name.3','product_name.4','product_name.5','id_state'],axis=1)

# %%
#Information about the data columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51296 entries, ES-2011-1630549 to IN-2011-71242
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_date      51296 non-null  datetime64[ns]
#  1   ship_date       51296 non-null  datetime64[ns]
#  2   ship_mode       51296 non-null  object
#  3   customer_name   51296 non-null  object
#  4   id_segment      51296 non-null  int64
#  5   segment         51296 non-null  object
#  6   state           51296 non-null  object
#  7   country         51296 non-null  object
#  8   market          51296 non-null  object
#  9   region          51296 non-null  object
#  10  product_id      51275 non-null  object
#  11  category        51296 non-null  object
#  12  sub_category    51296 non-null  object
#  13  product_name    51296 non-null  object
#  14  Unit Price      51296 non-null  int64
#  15  quantity        51296 non-null  int64
#  16  discount        51296 non-null  float64
#  17  shipping_cost   51296 non-null  float64
#  18  order_priority  51296 non-null  object
#  19  sales           51296 non-null  int64
#  20  expenses        51296 non-null  float64
#  21  revenue         51296 non-null  float64
#  22  year            51296 non-null  int64
# dtypes: datetime64[ns](2), float64(4), int64(5), object(12)
# memory usage: 9.4+ MB

# %%
data.shape
# Out:
# (51296, 23)

# %%
data.isnull().sum()
# Out:
# order_date         0
# ship_date          0
# ship_mode          0
# customer_name      0
# id_segment         0
# segment            0
# state              0
# country            0
# market             0
# region             0
# product_id        21
# category           0
# sub_category       0
# product_name       0
# Unit Price         0
# quantity           0
# discount           0
# shipping_cost      0
# order_priority     0
# sales              0
# expenses           0
# revenue            0
# year               0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isna().sum()
# Out:
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# id_segment        0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# Unit Price        0
# quantity          0
# discount          0
# shipping_cost     0
# order_priority    0
# sales             0
# expenses          0
# revenue           0
# year              0
# dtype: int64

# %%
data.columns.values
# Out:
# array(['order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'id_segment', 'segment', 'state', 'country', 'market', 'region',
#        'product_id', 'category', 'sub_category', 'product_name',
#        'Unit Price', 'quantity', 'discount', 'shipping_cost',
#        'order_priority', 'sales', 'expenses', 'revenue ', 'year'],
#       dtype=object)

# %% [markdown]
# <a name = "EDA"></a>
# ## 4. EDA(Exploratory Data Analysis)

# %%
fig = plt.figure(figsize = (10,6))
sns.violinplot(x = 'sales', y = 'ship_mode', data = data,palette='ocean')
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
sns.boxplot(x = 'id_segment', y = 'sales', data = data,palette='rocket')
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
sns.boxplot(x = 'sales', y = 'segment', data = data,palette='Purples')
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'market', y = 'sales', data = data,palette='rocket')
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'region', y = 'sales', data = data,palette='twilight')
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='sales', y='category', data=data, palette='autumn')
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'sub_category', y = 'sales', data = data,palette='Spectral')
plt.xticks(rotation=45)
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
up = data.groupby('Unit Price')['sales'].mean().reset_index()
plt.plot(up['Unit Price'],up['sales'])
plt.xlabel('Unit Price')
plt.ylabel('Average Sales')
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quantity', y = 'sales', data = data)
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
dis = data.groupby('discount')['sales'].mean().reset_index()
plt.plot(dis['discount'],dis['sales'])
plt.xlabel('Discount')
plt.ylabel('Average Sales')
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
sns.regplot(x = 'shipping_cost', y = 'sales', data = data, line_kws={"color": "red"}, 
            scatter_kws={"color": "blue"},ci=False)
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
sns.boxplot(x = 'sales', y = 'order_priority', data = data,palette='Reds')
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
sns.set_style("whitegrid")
sns.regplot(x = 'expenses', y = 'sales', data = data,line_kws={"color": sns.color_palette("dark")[1]}, 
            scatter_kws={"color": sns.color_palette("bright")[0]})
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
custom_palette = sns.color_palette(["#FFC0CB", "#00BFFF"])
sns.regplot(x = 'revenue ', y = 'sales', data = data, line_kws={"color": "red"}, 
            scatter_kws={"color": custom_palette[1]})
plt.xlabel('Revenue')
plt.ylabel('Average Sales')
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'year', y = 'sales', data = data,palette='rocket')
plt.show()

# %% [markdown]
# <a name = "Cleaning"></a>
# ## 5. Preprocessing Data

# %% [markdown]
# ### Handeling Categorical Attributes

# %%
data.columns
# Out:
# Index(['order_date', 'ship_date', 'ship_mode', 'customer_name', 'id_segment',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'Unit Price', 'quantity',
#        'discount', 'shipping_cost', 'order_priority', 'sales', 'expenses',
#        'revenue ', 'year'],
#       dtype='object')

# %%
print(data['ship_mode'].unique())
# Out:
# ['Standard Class' 'Same Day' 'First Class' 'Second Class']

# %%
dummies = pd.get_dummies(data["ship_mode"], prefix="ship-mode",drop_first=True)
data = pd.concat([data, dummies], axis=1)
data = data.drop("ship_mode", axis=1)

# %%
data['segment'].unique()
# Out:
# array(['Home Office', 'Corporate', 'Consumer'], dtype=object)

# %%
dummies = pd.get_dummies(data["segment"], prefix="seg",drop_first=True)
data = pd.concat([data,dummies],axis=1)
data = data.drop("segment",axis=1)

# %%
data['market'].unique()
# Out:
# array(['Africa', 'US', 'EMEA', 'APAC', 'EU', 'LATAM', 'Canada',
#        '            EU'], dtype=object)

# %%
dummies = pd.get_dummies(data["market"], prefix="mar",drop_first=True)
data = pd.concat([data,dummies],axis=1)
data = data.drop("market",axis=1)

# %%
data['region'].unique()
# Out:
# array(['Africa', 'West', 'EMEA', 'Central Asia', 'Central', 'South',
#        'North', 'Oceania', 'East', 'Southeast Asia', 'North Asia',
#        'Caribbean', 'Canada'], dtype=object)

# %%
dummies = pd.get_dummies(data["region"], prefix="reg",drop_first=True)
data = pd.concat([data,dummies],axis=1)
data = data.drop("region",axis=1)

# %%
data['category'].unique()
# Out:
# array(['OFFICE SUPPLIES', 'TECHNOLOGY', 'FURNITURE'], dtype=object)

# %%
dummies = pd.get_dummies(data["category"], prefix="cat",drop_first=True)
data = pd.concat([data,dummies],axis=1)
data = data.drop("category",axis=1)

# %%
data['sub_category'].unique()
# Out:
# array(['ART', 'SUPPLIES', 'STORAGE', 'ENVELOPES', 'PHONES', 'PAPER',
#        'ACCESSORIES', 'APPLIANCES', 'COPIERS', 'LABELS', 'CHAIRS',
#        'FURNISHINGS', 'BINDERS', 'FASTENERS', 'TABLES', 'BOOKCASES',
#        'MACHINES'], dtype=object)

# %%
dummies = pd.get_dummies(data["sub_category"], prefix="sub_cat",drop_first=True)
data = pd.concat([data,dummies],axis=1)
data = data.drop("sub_category",axis=1)

# %%
data['order_priority'].unique()
# Out:
# array(['Medium', 'High', 'Low', 'Critical'], dtype=object)

# %%
dummies = pd.get_dummies(data["order_priority"], prefix="ord",drop_first=True)
data = pd.concat([data,dummies],axis=1)
data = data.drop("order_priority",axis=1)

# %%
le = LabelEncoder()
data["country"] = le.fit_transform(data["country"])

# %%
le = LabelEncoder()
data["state"] = le.fit_transform(data["state"])

# %%
data.head()
# Out:
#                 order_date  ship_date    customer_name  id_segment  state  \
# order_id
# ES-2011-1630549 2011-04-16 2011-04-21    Dianna Wilson           2      3
# MX-2013-132906  2012-05-25 2012-05-30        Denny Joy           3      3
# MX-2013-113579  2012-07-13 2012-07-17  Arthur Wiediger           2      3
# CA-2013-116337  2012-09-04 2012-09-08      Dean Braden           1      3
# ES-2013-4232414 2012-09-04 2012-09-08      Dean Braden           1      3
#
#                  country        product_id             product_name  \
# order_id
# ES-2011-1630549       94  OFF-BOS-10001348  Boston Pencil Sharpener
# MX-2013-132906        94  OFF-FIS-10001797          Fiskars Trimmer
# MX-2013-113579        94  OFF-SME-10001718                Smead Box
# CA-2013-116337        94  OFF-SME-10001718                Smead Box
# ES-2013-4232414       94  OFF-BIN-10004512      Binney & Smith Pens
#
#                  Unit Price  quantity  discount  shipping_cost  sales  \
# order_id
# ES-2011-1630549         117        14       0.7          10.61   1638
# MX-2013-132906          274         1       0.7           0.20    274
# MX-2013-113579          439         1       0.7           0.26    439
# CA-2013-116337           28         2       0.7           0.58     56
# ES-2013-4232414         344         2       0.7           0.41    688
#
#                  expenses  revenue   year  ship-mode_Same Day  \
# order_id
# ES-2011-1630549  436.7487    502.01  2011                   0
# MX-2013-132906    71.6880     82.40  2012                   0
# MX-2013-113579   114.8052    131.96  2012                   0
# CA-2013-116337    15.1206     17.38  2012                   0
# ES-2013-4232414  179.9247    206.81  2012                   0
#
#                  ship-mode_Second Class  ship-mode_Standard Class  \
# order_id
# ES-2011-1630549                       0                         1
# MX-2013-132906                        0                         1
# MX-2013-113579                        0                         1
# CA-2013-116337                        0                         1
# ES-2013-4232414                       0                         1
#
#                  seg_Corporate  seg_Home Office  mar_APAC  mar_Africa  \
# order_id
# ES-2011-1630549              0                1         0           1
# MX-2013-132906               1                0         0           1
# MX-2013-113579               0                1         0           1
# CA-2013-116337               0                0         0           1
# ES-2013-4232414              0                0         0           1
#
#                  mar_Canada  mar_EMEA  mar_EU  mar_LATAM  mar_US  reg_Canada  \
# order_id
# ES-2011-1630549           0         0       0          0       0           0
# MX-2013-132906            0         0       0          0       0           0
# MX-2013-113579            0         0       0          0       0           0
# CA-2013-116337            0         0       0          0       0           0
# ES-2013-4232414           0         0       0          0       0           0
#
#                  reg_Caribbean  reg_Central  reg_Central Asia  reg_EMEA  \
# order_id
# ES-2011-1630549              0            0                 0         0
# MX-2013-132906               0            0                 0         0
# MX-2013-113579               0            0                 0         0
# CA-2013-116337               0            0                 0         0
# ES-2013-4232414              0            0                 0         0
#
#                  reg_East  reg_North  reg_North Asia  reg_Oceania  reg_South  \
# order_id
# ES-2011-1630549         0          0               0            0          0
# MX-2013-132906          0          0               0            0          0
# MX-2013-113579          0          0               0            0          0
# CA-2013-116337          0          0               0            0          0
# ES-2013-4232414         0          0               0            0          0
#
#                  reg_Southeast Asia  reg_West  cat_OFFICE SUPPLIES  \
# order_id
# ES-2011-1630549                   0         0                    1
# MX-2013-132906                    0         0                    1
# MX-2013-113579                    0         0                    1
# CA-2013-116337                    0         0                    1
# ES-2013-4232414                   0         0                    1
#
#                  cat_TECHNOLOGY  sub_cat_APPLIANCES  sub_cat_ART  \
# order_id
# ES-2011-1630549               0                   0            1
# MX-2013-132906                0                   0            0
# MX-2013-113579                0                   0            0
# CA-2013-116337                0                   0            0
# ES-2013-4232414               0                   0            1
#
#                  sub_cat_BINDERS  sub_cat_BOOKCASES  sub_cat_CHAIRS  \
# order_id
# ES-2011-1630549                0                  0               0
# MX-2013-132906                 0                  0               0
# MX-2013-113579                 0                  0               0
# CA-2013-116337                 0                  0               0
# ES-2013-4232414                0                  0               0
#
#                  sub_cat_COPIERS  sub_cat_ENVELOPES  sub_cat_FASTENERS  \
# order_id
# ES-2011-1630549                0                  0                  0
# MX-2013-132906                 0                  0                  0
# MX-2013-113579                 0                  0                  0
# CA-2013-116337                 0                  0                  0
# ES-2013-4232414                0                  0                  0
#
#                  sub_cat_FURNISHINGS  sub_cat_LABELS  sub_cat_MACHINES  \
# order_id
# ES-2011-1630549                    0               0                 0
# MX-2013-132906                     0               0                 0
# MX-2013-113579                     0               0                 0
# CA-2013-116337                     0               0                 0
# ES-2013-4232414                    0               0                 0
#
#                  sub_cat_PAPER  sub_cat_PHONES  sub_cat_STORAGE  \
# order_id
# ES-2011-1630549              0               0                0
# MX-2013-132906               0               0                0
# MX-2013-113579               0               0                1
# CA-2013-116337               0               0                1
# ES-2013-4232414              0               0                0
#
#                  sub_cat_SUPPLIES  sub_cat_TABLES  ord_High  ord_Low  \
# order_id
# ES-2011-1630549                 0               0         0        0
# MX-2013-132906                  1               0         0        0
# MX-2013-113579                  0               0         0        0
# CA-2013-116337                  0               0         0        0
# ES-2013-4232414                 0               0         0        0
#
#                  ord_Medium
# order_id
# ES-2011-1630549           1
# MX-2013-132906            1
# MX-2013-113579            1
# CA-2013-116337            1
# ES-2013-4232414           1

# %%
object_cols = data.select_dtypes(include=["object"])

num_object_cols = len(object_cols.columns)
print(num_object_cols)
# Out:
# 3

# %%
object_cols = data.select_dtypes(include=["datetime64"])

num_object_cols = len(object_cols.columns)
print(num_object_cols)
# Out:
# 2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51275 entries, ES-2011-1630549 to IN-2011-71242
# Data columns (total 61 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   order_date                51275 non-null  datetime64[ns]
#  1   ship_date                 51275 non-null  datetime64[ns]
#  2   customer_name             51275 non-null  object
#  3   id_segment                51275 non-null  int64
#  4   state                     51275 non-null  int32
#  5   country                   51275 non-null  int32
#  6   product_id                51275 non-null  object
#  7   product_name              51275 non-null  object
#  8   Unit Price                51275 non-null  int64
#  9   quantity                  51275 non-null  int64
#  10  discount                  51275 non-null  float64
#  11  shipping_cost             51275 non-null  float64
#  12  sales                     51275 non-null  int64
#  13  expenses                  51275 non-null  float64
#  14  revenue                   51275 non-null  float64
#  15  year                      51275 non-null  int64
#  16  ship-mode_Same Day        51275 non-null  uint8
#  17  ship-mode_Second Class    51275 non-null  uint8
#  18  ship-mode_Standard Class  51275 non-null  uint8
#  19  seg_Corporate             51275 non-null  uint8
#  20  seg_Home Office           51275 non-null  uint8
#  21  mar_APAC                  51275 non-null  uint8
#  22  mar_Africa                51275 non-null  uint8
#  23  mar_Canada                51275 non-null  uint8
#  24  mar_EMEA                  51275 non-null  uint8
#  25  mar_EU                    51275 non-null  uint8
#  26  mar_LATAM                 51275 non-null  uint8
#  27  mar_US                    51275 non-null  uint8
#  28  reg_Canada                51275 non-null  uint8
#  29  reg_Caribbean             51275 non-null  uint8
#  30  reg_Central               51275 non-null  uint8
#  31  reg_Central Asia          51275 non-null  uint8
#  32  reg_EMEA                  51275 non-null  uint8
#  33  reg_East                  51275 non-null  uint8
#  34  reg_North                 51275 non-null  uint8
#  35  reg_North Asia            51275 non-null  uint8
#  36  reg_Oceania               51275 non-null  uint8
#  37  reg_South                 51275 non-null  uint8
#  38  reg_Southeast Asia        51275 non-null  uint8
#  39  reg_West                  51275 non-null  uint8
#  40  cat_OFFICE SUPPLIES       51275 non-null  uint8
#  41  cat_TECHNOLOGY            51275 non-null  uint8
#  42  sub_cat_APPLIANCES        51275 non-null  uint8
#  43  sub_cat_ART               51275 non-null  uint8
#  44  sub_cat_BINDERS           51275 non-null  uint8
#  45  sub_cat_BOOKCASES         51275 non-null  uint8
#  46  sub_cat_CHAIRS            51275 non-null  uint8
#  47  sub_cat_COPIERS           51275 non-null  uint8
#  48  sub_cat_ENVELOPES         51275 non-null  uint8
#  49  sub_cat_FASTENERS         51275 non-null  uint8
#  50  sub_cat_FURNISHINGS       51275 non-null  uint8
#  51  sub_cat_LABELS            51275 non-null  uint8
#  52  sub_cat_MACHINES          51275 non-null  uint8
#  53  sub_cat_PAPER             51275 non-null  uint8
#  54  sub_cat_PHONES            51275 non-null  uint8
#  55  sub_cat_STORAGE           51275 non-null  uint8
#  56  sub_cat_SUPPLIES          51275 non-null  uint8
#  57  sub_cat_TABLES            51275 non-null  uint8
#  58  ord_High                  51275 non-null  uint8
#  59  ord_Low                   51275 non-null  uint8
#  60  ord_Medium                51275 non-null  uint8
# dtypes: datetime64[ns](2), float64(4), int32(2), int64(5), object(3), uint8(45)
# memory usage: 10.5+ MB

# %%
data.drop(['order_date','ship_date','product_id','product_name','customer_name'],axis=1,inplace=True)

# %% [markdown]
# <a name = "Correlations"></a>
# ## 6.Correlations & Distributions

# %%
# Visualizing the collelations between all variables of the data.
plt.figure(1 , figsize = (30,20))
cor = sns.heatmap(data.corr(), annot = True)
cor.set_title('Correlation Heatmap', fontdict={'fontsize':25},color="red" ,pad=12)
plt.show()

# %%
plt.figure(1 , figsize = (20,10))
data.corr()['sales'].sort_values(ascending = False).plot(kind='bar', color=['#1f77b4','#ff7f0e', '#2ca02c', '#d62728', '#9467bd','#8c564b','#e377c2','#7f7f7f','#bcbd22','#17becf'])
plt.show()

# %%
len(data.columns)
# Out:
# 56

# %%
# Top 20 correlated features to the target
top20_corrs = abs(data.corr()['sales']).sort_values(ascending = False).head(20)
top20_corrs
# Out:
# sales                 1.000000
# expenses              0.939793
# revenue               0.939793
# quantity              0.715229
# Unit Price            0.584234
# shipping_cost         0.191416
# mar_EMEA              0.126286
# reg_EMEA              0.126286
# mar_Africa            0.119964
# mar_US                0.054542
# reg_Central           0.048155
# mar_APAC              0.046430
# mar_EU                0.042999
# mar_LATAM             0.042028
# reg_South             0.037442
# reg_Canada            0.031666
# mar_Canada            0.031666
# reg_West              0.029265
# reg_Southeast Asia    0.027870
# reg_East              0.027278
# Name: sales, dtype: float64

# %%
# # Quantify correlations between features
# corr = data[list(top20_corrs.index)].corr()
# plt.figure(figsize = (20, 10))
# sns.heatmap(corr, cmap='YlOrRd', annot = True, center = 0)
# plt.title('Correlogram', fontsize = 15, color = 'red')
# plt.show()

# %%
data1 =data.drop('sales',axis=1)

# %%
corr_matrix = data1.corr()

# Identify highly correlated features
high_corr_features = set()
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) > 0.8:
            colname = corr_matrix.columns[i]
            high_corr_features.add(colname)

# Drop highly correlated features
data.drop(high_corr_features, axis=1, inplace=True)

# Print the remaining features
print(data.columns)
# Out:
# Index(['id_segment', 'state', 'country', 'Unit Price', 'quantity', 'discount',
#        'shipping_cost', 'sales', 'expenses', 'year', 'ship-mode_Same Day',
#        'ship-mode_Second Class', 'ship-mode_Standard Class', 'seg_Home Office',
#        'mar_APAC', 'mar_Africa', 'mar_Canada', 'mar_EMEA', 'mar_EU',
#        'mar_LATAM', 'mar_US', 'reg_Caribbean', 'reg_Central',
#        'reg_Central Asia', 'reg_East', 'reg_North', 'reg_North Asia',
#        'reg_Oceania', 'reg_South', 'reg_Southeast Asia', 'reg_West',
#        'cat_OFFICE SUPPLIES', 'cat_TECHNOLOGY', 'sub_cat_APPLIANCES',
#        'sub_cat_ART', 'sub_cat_BINDERS', 'sub_cat_BOOKCASES', 'sub_cat_CHAIRS',
#        'sub_cat_COPIERS', 'sub_cat_ENVELOPES', 'sub_cat_FASTENERS',
#        'sub_cat_FURNISHINGS', 'sub_cat_LABELS', 'sub_cat_MACHINES',
#        'sub_cat_PAPER', 'sub_cat_PHONES', 'sub_cat_STORAGE',
#        'sub_cat_SUPPLIES', 'sub_cat_TABLES', 'ord_High', 'ord_Low',
#        'ord_Medium'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 52

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51275 entries, ES-2011-1630549 to IN-2011-71242
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id_segment                51275 non-null  int64
#  1   state                     51275 non-null  int32
#  2   country                   51275 non-null  int32
#  3   Unit Price                51275 non-null  int64
#  4   quantity                  51275 non-null  int64
#  5   discount                  51275 non-null  float64
#  6   shipping_cost             51275 non-null  float64
#  7   sales                     51275 non-null  int64
#  8   expenses                  51275 non-null  float64
#  9   year                      51275 non-null  int64
#  10  ship-mode_Same Day        51275 non-null  uint8
#  11  ship-mode_Second Class    51275 non-null  uint8
#  12  ship-mode_Standard Class  51275 non-null  uint8
#  13  seg_Home Office           51275 non-null  uint8
#  14  mar_APAC                  51275 non-null  uint8
#  15  mar_Africa                51275 non-null  uint8
#  16  mar_Canada                51275 non-null  uint8
#  17  mar_EMEA                  51275 non-null  uint8
#  18  mar_EU                    51275 non-null  uint8
#  19  mar_LATAM                 51275 non-null  uint8
#  20  mar_US                    51275 non-null  uint8
#  21  reg_Caribbean             51275 non-null  uint8
#  22  reg_Central               51275 non-null  uint8
#  23  reg_Central Asia          51275 non-null  uint8
#  24  reg_East                  51275 non-null  uint8
#  25  reg_North                 51275 non-null  uint8
#  26  reg_North Asia            51275 non-null  uint8
#  27  reg_Oceania               51275 non-null  uint8
#  28  reg_South                 51275 non-null  uint8
#  29  reg_Southeast Asia        51275 non-null  uint8
#  30  reg_West                  51275 non-null  uint8
#  31  cat_OFFICE SUPPLIES       51275 non-null  uint8
#  32  cat_TECHNOLOGY            51275 non-null  uint8
#  33  sub_cat_APPLIANCES        51275 non-null  uint8
#  34  sub_cat_ART               51275 non-null  uint8
#  35  sub_cat_BINDERS           51275 non-null  uint8
#  36  sub_cat_BOOKCASES         51275 non-null  uint8
#  37  sub_cat_CHAIRS            51275 non-null  uint8
#  38  sub_cat_COPIERS           51275 non-null  uint8
#  39  sub_cat_ENVELOPES         51275 non-null  uint8
#  40  sub_cat_FASTENERS         51275 non-null  uint8
#  41  sub_cat_FURNISHINGS       51275 non-null  uint8
#  42  sub_cat_LABELS            51275 non-null  uint8
#  43  sub_cat_MACHINES          51275 non-null  uint8
#  44  sub_cat_PAPER             51275 non-null  uint8
#  45  sub_cat_PHONES            51275 non-null  uint8
#  46  sub_cat_STORAGE           51275 non-null  uint8
#  47  sub_cat_SUPPLIES          51275 non-null  uint8
#  48  sub_cat_TABLES            51275 non-null  uint8
#  49  ord_High                  51275 non-null  uint8
#  50  ord_Low                   51275 non-null  uint8
#  51  ord_Medium                51275 non-null  uint8
# dtypes: float64(3), int32(2), int64(5), uint8(42)
# memory usage: 8.0+ MB

# %% [markdown]
# ### Scatter Matrix

# %%
# sns.set()
# sns.pairplot(data)
# plt.figure(1 , figsize = (20,10))
# plt.show()

# %% [markdown]
# ### Features Distributions & Normalization

# %% [markdown]
# Now I'm gonna normalize our attributes using Feature Scaling and the box-cox transformation .

# %% [markdown]
# ##### Unit Price

# %%
data['Unit Price'].plot(kind='kde')
plt.show()

# %%
scaler = MinMaxScaler()
normalized_column = scaler.fit_transform(data[['Unit Price']])
data['Unit Price'] = normalized_column

# %%
data['Unit Price'].plot(kind='kde')
plt.show()

# %% [markdown]
# ##### Shipping Cost

# %%
data['shipping_cost'].plot(kind='kde')
plt.show()

# %%
data['shipping_cost'].plot(kind='hist')
plt.show()

# %%
shifted_shipping_cost =data['shipping_cost'] + np.finfo(float).eps
transformed_shipping_cost, _ = stats.boxcox(shifted_shipping_cost)
data['shipping_cost'] = transformed_shipping_cost

# %%
data['shipping_cost'].plot(kind='kde')
plt.show()

# %% [markdown]
# ##### Expenses

# %%
data['expenses'].plot(kind='kde')
plt.show()

# %%
data['expenses'].plot(kind='hist')
plt.show()

# %%
data['expenses'], _ = pd.Series(stats.boxcox(data['expenses']))

# %%
data['expenses'].plot(kind='kde')
plt.show()

# %% [markdown]
# ### Handeling Unbalanced data

# %%
plt.figure(1 , figsize = (20,10))
plt.hist(data['sales'], bins=50)
plt.xlabel('Sales',size=14)
plt.ylabel('Count',size=14)
plt.title('Distribution of Target Variable',size=20)
plt.show()

# %%
mean = data['sales'].mean()
median = data['sales'].median()
std_dev = data['sales'].std()

print('Mean:', mean)
print('Median:', median)
print('Standard Deviation:', std_dev)
# Out:
# Mean: 826.3619112627987
# Median: 605.0
# Standard Deviation: 752.7489740694216

# %% [markdown]
# We can see that the data is skewed to the left that means it's unbalanced based on the statistics and the distribution of the target variable so we need to use a different evaluation metric such as the mean absolute error (MAE) or root mean squared error (RMSE) instead of the mean squared error (MSE) or R-squared .

# %% [markdown]
# Also we can try normalizing it with the box-cox transformation for example that could help .

# %% [markdown]
# ### Box-Cox Transformation

# %%
data['sales'], _ = pd.Series(stats.boxcox(data['sales']))

# %%
plt.figure(1 , figsize = (20,10))
plt.hist(data['sales'], bins=50)
plt.xlabel('Sales',size=14)
plt.ylabel('Count',size=14)
plt.title('Distribution of Target Variable',size=20)
plt.show()

# %%
mean = data['sales'].mean()
median = data['sales'].median()
std_dev = data['sales'].std()

print('Mean:', mean)
print('Median:', median)
print('Standard Deviation:', std_dev)
# Out:
# Mean: 11.901548984321025
# Median: 11.962572470227117
# Standard Deviation: 2.9719160755419174

# %%
data.head()
# Out:
#                  id_segment  state  country  Unit Price  quantity  discount  \
# order_id
# ES-2011-1630549           2      3       94    0.223744        14       0.7
# MX-2013-132906            3      3       94    0.582192         1       0.7
# MX-2013-113579            2      3       94    0.958904         1       0.7
# CA-2013-116337            1      3       94    0.020548         2       0.7
# ES-2013-4232414           1      3       94    0.742009         2       0.7
#
#                  shipping_cost      sales   expenses  year  \
# order_id
# ES-2011-1630549       2.458229  15.376721  10.774926  2011
# MX-2013-132906       -1.566614   9.648513   6.327482  2012
# MX-2013-113579       -1.316986  10.986060   7.355916  2012
# CA-2013-116337       -0.539763   5.887143   3.468168  2012
# ES-2013-4232414      -0.878350  12.369943   8.418531  2012
#
#                  ship-mode_Same Day  ship-mode_Second Class  \
# order_id
# ES-2011-1630549                   0                       0
# MX-2013-132906                    0                       0
# MX-2013-113579                    0                       0
# CA-2013-116337                    0                       0
# ES-2013-4232414                   0                       0
#
#                  ship-mode_Standard Class  seg_Home Office  mar_APAC  \
# order_id
# ES-2011-1630549                         1                1         0
# MX-2013-132906                          1                0         0
# MX-2013-113579                          1                1         0
# CA-2013-116337                          1                0         0
# ES-2013-4232414                         1                0         0
#
#                  mar_Africa  mar_Canada  mar_EMEA  mar_EU  mar_LATAM  mar_US  \
# order_id
# ES-2011-1630549           1           0         0       0          0       0
# MX-2013-132906            1           0         0       0          0       0
# MX-2013-113579            1           0         0       0          0       0
# CA-2013-116337            1           0         0       0          0       0
# ES-2013-4232414           1           0         0       0          0       0
#
#                  reg_Caribbean  reg_Central  reg_Central Asia  reg_East  \
# order_id
# ES-2011-1630549              0            0                 0         0
# MX-2013-132906               0            0                 0         0
# MX-2013-113579               0            0                 0         0
# CA-2013-116337               0            0                 0         0
# ES-2013-4232414              0            0                 0         0
#
#                  reg_North  reg_North Asia  reg_Oceania  reg_South  \
# order_id
# ES-2011-1630549          0               0            0          0
# MX-2013-132906           0               0            0          0
# MX-2013-113579           0               0            0          0
# CA-2013-116337           0               0            0          0
# ES-2013-4232414          0               0            0          0
#
#                  reg_Southeast Asia  reg_West  cat_OFFICE SUPPLIES  \
# order_id
# ES-2011-1630549                   0         0                    1
# MX-2013-132906                    0         0                    1
# MX-2013-113579                    0         0                    1
# CA-2013-116337                    0         0                    1
# ES-2013-4232414                   0         0                    1
#
#                  cat_TECHNOLOGY  sub_cat_APPLIANCES  sub_cat_ART  \
# order_id
# ES-2011-1630549               0                   0            1
# MX-2013-132906                0                   0            0
# MX-2013-113579                0                   0            0
# CA-2013-116337                0                   0            0
# ES-2013-4232414               0                   0            1
#
#                  sub_cat_BINDERS  sub_cat_BOOKCASES  sub_cat_CHAIRS  \
# order_id
# ES-2011-1630549                0                  0               0
# MX-2013-132906                 0                  0               0
# MX-2013-113579                 0                  0               0
# CA-2013-116337                 0                  0               0
# ES-2013-4232414                0                  0               0
#
#                  sub_cat_COPIERS  sub_cat_ENVELOPES  sub_cat_FASTENERS  \
# order_id
# ES-2011-1630549                0                  0                  0
# MX-2013-132906                 0                  0                  0
# MX-2013-113579                 0                  0                  0
# CA-2013-116337                 0                  0                  0
# ES-2013-4232414                0                  0                  0
#
#                  sub_cat_FURNISHINGS  sub_cat_LABELS  sub_cat_MACHINES  \
# order_id
# ES-2011-1630549                    0               0                 0
# MX-2013-132906                     0               0                 0
# MX-2013-113579                     0               0                 0
# CA-2013-116337                     0               0                 0
# ES-2013-4232414                    0               0                 0
#
#                  sub_cat_PAPER  sub_cat_PHONES  sub_cat_STORAGE  \
# order_id
# ES-2011-1630549              0               0                0
# MX-2013-132906               0               0                0
# MX-2013-113579               0               0                1
# CA-2013-116337               0               0                1
# ES-2013-4232414              0               0                0
#
#                  sub_cat_SUPPLIES  sub_cat_TABLES  ord_High  ord_Low  \
# order_id
# ES-2011-1630549                 0               0         0        0
# MX-2013-132906                  1               0         0        0
# MX-2013-113579                  0               0         0        0
# CA-2013-116337                  0               0         0        0
# ES-2013-4232414                 0               0         0        0
#
#                  ord_Medium
# order_id
# ES-2011-1630549           1
# MX-2013-132906            1
# MX-2013-113579            1
# CA-2013-116337            1
# ES-2013-4232414           1

# %% [markdown]
# <a name = "Splitting"></a>
# ## 7.Splitting the Data

# %% [markdown]
# ### Standardization:

# %%
y=data[['sales']]
x=data.drop(['sales'],axis=1)

# %%
#Applying Standard scaling to get optimized result
sc = StandardScaler()

# %%
columns =x.columns

# %%
x = sc.fit_transform(x)

# %%
x = pd.DataFrame(x,columns=columns)

# %%
x.describe()
# Out:
#          id_segment         state       country    Unit Price      quantity  \
# count  5.127500e+04  5.127500e+04  5.127500e+04  5.127500e+04  5.127500e+04
# mean  -1.344176e-17  3.547517e-17 -1.441179e-17  2.059223e-16  3.686092e-17
# std    1.000010e+00  1.000010e+00  1.000010e+00  1.000010e+00  1.000010e+00
# min   -8.924283e-01 -1.845893e+00 -1.693707e+00 -1.732146e+00 -1.086769e+00
# 25%   -8.924283e-01 -8.232760e-01 -7.512360e-01 -8.688930e-01 -6.479206e-01
# 50%   -8.924283e-01  3.493329e-02  4.129644e-02  2.279932e-03 -2.090724e-01
# 75%    1.385228e+00  8.503965e-01  1.176546e+00  8.655332e-01  6.686241e-01
# max    1.385228e+00  1.748064e+00  1.433583e+00  1.736706e+00  4.618258e+00
#
#            discount  shipping_cost      expenses          year  \
# count  5.127500e+04   5.127500e+04  5.127500e+04  5.127500e+04
# mean  -1.324776e-16  -9.173658e-17  2.075852e-16  8.916740e-14
# std    1.000010e+00   1.000010e+00  1.000010e+00  1.000010e+00
# min   -6.732217e-01  -1.340315e+01 -3.216828e+00 -1.024865e+01
# 25%   -6.732217e-01  -7.086727e-01 -6.906824e-01 -6.768205e-01
# 50%   -6.732217e-01  -4.034887e-02 -1.633339e-03  1.933458e-01
# 75%    2.689468e-01   6.852841e-01  6.919160e-01  1.063512e+00
# max    3.330994e+00   3.192516e+00  3.207126e+00  6.545581e+01
#
#        ship-mode_Same Day  ship-mode_Second Class  ship-mode_Standard Class  \
# count        5.127500e+04            5.127500e+04              5.127500e+04
# mean         5.542996e-19           -4.184962e-17              2.120196e-17
# std          1.000010e+00            1.000010e+00              1.000010e+00
# min         -2.357629e-01           -5.016145e-01             -1.224795e+00
# 25%         -2.357629e-01           -5.016145e-01             -1.224795e+00
# 50%         -2.357629e-01           -5.016145e-01              8.164634e-01
# 75%         -2.357629e-01           -5.016145e-01              8.164634e-01
# max          4.241549e+00            1.993563e+00              8.164634e-01
#
#        seg_Home Office      mar_APAC    mar_Africa    mar_Canada  \
# count     5.127500e+04  5.127500e+04  5.127500e+04  5.127500e+04
# mean     -4.711546e-18 -2.771498e-17 -7.898769e-17  3.741522e-17
# std       1.000010e+00  1.000010e+00  1.000010e+00  1.000010e+00
# min      -4.719073e-01 -5.225505e-01 -3.134078e-01 -8.686506e-02
# 25%      -4.719073e-01 -5.225505e-01 -3.134078e-01 -8.686506e-02
# 50%      -4.719073e-01 -5.225505e-01 -3.134078e-01 -8.686506e-02
# 75%      -4.719073e-01 -5.225505e-01 -3.134078e-01 -8.686506e-02
# max       2.119060e+00  1.913690e+00  3.190732e+00  1.151211e+01
#
#            mar_EMEA        mar_EU     mar_LATAM        mar_US  reg_Caribbean  \
# count  5.127500e+04  5.127500e+04  5.127500e+04  5.127500e+04   5.127500e+04
# mean  -8.397638e-17  1.219459e-16 -6.651595e-17  2.771498e-17   3.048648e-17
# std    1.000010e+00  1.000010e+00  1.000010e+00  1.000010e+00   1.000010e+00
# min   -3.297280e-01 -4.920334e-01 -5.011272e-01 -4.919722e-01  -1.846720e-01
# 25%   -3.297280e-01 -4.920334e-01 -5.011272e-01 -4.919722e-01  -1.846720e-01
# 50%   -3.297280e-01 -4.920334e-01 -5.011272e-01 -4.919722e-01  -1.846720e-01
# 75%   -3.297280e-01 -4.920334e-01 -5.011272e-01 -4.919722e-01  -1.846720e-01
# max    3.032803e+00  2.032382e+00  1.995501e+00  2.032635e+00   5.415006e+00
#
#         reg_Central  reg_Central Asia      reg_East     reg_North  \
# count  5.127500e+04      5.127500e+04  5.127500e+04  5.127500e+04
# mean  -3.325797e-17     -2.785355e-17  9.423092e-18 -3.131792e-17
# std    1.000010e+00      1.000010e+00  1.000010e+00  1.000010e+00
# min   -5.259665e-01     -2.038648e-01 -2.424630e-01 -3.207459e-01
# 25%   -5.259665e-01     -2.038648e-01 -2.424630e-01 -3.207459e-01
# 50%   -5.259665e-01     -2.038648e-01 -2.424630e-01 -3.207459e-01
# 75%   -5.259665e-01     -2.038648e-01 -2.424630e-01 -3.207459e-01
# max    1.901262e+00      4.905211e+00  4.124341e+00  3.117733e+00
#
#        reg_North Asia   reg_Oceania     reg_South  reg_Southeast Asia  \
# count    5.127500e+04  5.127500e+04  5.127500e+04        5.127500e+04
# mean    -1.441179e-17 -3.547517e-17 -6.651595e-18        8.757933e-17
# std      1.000010e+00  1.000010e+00  1.000010e+00        1.000010e+00
# min     -2.185766e-01 -2.700845e-01 -3.858638e-01       -2.548876e-01
# 25%     -2.185766e-01 -2.700845e-01 -3.858638e-01       -2.548876e-01
# 50%     -2.185766e-01 -2.700845e-01 -3.858638e-01       -2.548876e-01
# 75%     -2.185766e-01 -2.700845e-01 -3.858638e-01       -2.548876e-01
# max      4.575056e+00  3.702544e+00  2.591588e+00        3.923298e+00
#
#            reg_West  cat_OFFICE SUPPLIES  cat_TECHNOLOGY  sub_cat_APPLIANCES  \
# count  5.127500e+04         5.127500e+04    5.127500e+04        5.127500e+04
# mean   2.217198e-17        -9.755672e-17    8.356066e-17       -4.295822e-18
# std    1.000010e+00         1.000010e+00    1.000010e+00        1.000010e+00
# min   -2.580834e-01        -1.249988e+00   -4.964016e-01       -1.882557e-01
# 25%   -2.580834e-01        -1.249988e+00   -4.964016e-01       -1.882557e-01
# 50%   -2.580834e-01         8.000080e-01   -4.964016e-01       -1.882557e-01
# 75%   -2.580834e-01         8.000080e-01   -4.964016e-01       -1.882557e-01
# max    3.874717e+00         8.000080e-01    2.014498e+00        5.311923e+00
#
#         sub_cat_ART  sub_cat_BINDERS  sub_cat_BOOKCASES  sub_cat_CHAIRS  \
# count  5.127500e+04     5.127500e+04       5.127500e+04    5.127500e+04
# mean  -3.557910e-17    -8.065058e-17      -3.772701e-17    7.483044e-17
# std    1.000010e+00     1.000010e+00       1.000010e+00    1.000010e+00
# min   -3.243939e-01    -3.691381e-01      -2.220801e-01   -2.679168e-01
# 25%   -3.243939e-01    -3.691381e-01      -2.220801e-01   -2.679168e-01
# 50%   -3.243939e-01    -3.691381e-01      -2.220801e-01   -2.679168e-01
# 75%   -3.243939e-01    -3.691381e-01      -2.220801e-01   -2.679168e-01
# max    3.082672e+00     2.709014e+00       4.502881e+00    3.732501e+00
#
#        sub_cat_COPIERS  sub_cat_ENVELOPES  sub_cat_FASTENERS  \
# count     5.127500e+04       5.127500e+04       5.127500e+04
# mean      2.265699e-17      -7.205894e-18      -3.990957e-17
# std       1.000010e+00       1.000010e+00       1.000010e+00
# min      -2.128331e-01      -2.233342e-01      -2.225148e-01
# 25%      -2.128331e-01      -2.233342e-01      -2.225148e-01
# 50%      -2.128331e-01      -2.233342e-01      -2.225148e-01
# 75%      -2.128331e-01      -2.233342e-01      -2.225148e-01
# max       4.698517e+00       4.477594e+00       4.494082e+00
#
#        sub_cat_FURNISHINGS  sub_cat_LABELS  sub_cat_MACHINES  sub_cat_PAPER  \
# count         5.127500e+04    5.127500e+04      5.127500e+04   5.127500e+04
# mean          5.376706e-17   -3.194151e-17      5.889433e-17   2.674495e-17
# std           1.000010e+00    1.000010e+00      1.000010e+00   1.000010e+00
# min          -2.566620e-01   -2.313987e-01     -1.727598e-01  -2.722396e-01
# 25%          -2.566620e-01   -2.313987e-01     -1.727598e-01  -2.722396e-01
# 50%          -2.566620e-01   -2.313987e-01     -1.727598e-01  -2.722396e-01
# 75%          -2.566620e-01   -2.313987e-01     -1.727598e-01  -2.722396e-01
# max           3.896175e+00    4.321545e+00      5.788384e+00   3.673234e+00
#
#        sub_cat_PHONES  sub_cat_STORAGE  sub_cat_SUPPLIES  sub_cat_TABLES  \
# count    5.127500e+04     5.127500e+04      5.127500e+04    5.127500e+04
# mean    -3.228795e-17    -5.016411e-17      3.717271e-17   -2.577493e-17
# std      1.000010e+00     1.000010e+00      1.000010e+00    1.000010e+00
# min     -2.645988e-01    -3.307450e-01     -2.227561e-01   -1.306079e-01
# 25%     -2.645988e-01    -3.307450e-01     -2.227561e-01   -1.306079e-01
# 50%     -2.645988e-01    -3.307450e-01     -2.227561e-01   -1.306079e-01
# 75%     -2.645988e-01    -3.307450e-01     -2.227561e-01   -1.306079e-01
# max      3.779307e+00     3.023477e+00      4.489215e+00    7.656507e+00
#
#            ord_High       ord_Low    ord_Medium
# count  5.127500e+04  5.127500e+04  5.127500e+04
# mean   7.469186e-17 -5.210416e-17 -1.324776e-16
# std    1.000010e+00  1.000010e+00  1.000010e+00
# min   -6.582275e-01 -2.227079e-01 -1.160327e+00
# 25%   -6.582275e-01 -2.227079e-01 -1.160327e+00
# 50%   -6.582275e-01 -2.227079e-01  8.618257e-01
# 75%    1.519232e+00 -2.227079e-01  8.618257e-01
# max    1.519232e+00  4.490187e+00  8.618257e-01

# %%
x.head()
# Out:
#    id_segment     state   country  Unit Price  quantity  discount  \
# 0    0.246400 -1.836029  0.319754   -0.956010  4.618258  2.624368
# 1    1.385228 -1.836029  0.319754    0.287391 -1.086769  2.624368
# 2    0.246400 -1.836029  0.319754    1.594151 -1.086769  2.624368
# 3   -0.892428 -1.836029  0.319754   -1.660868 -0.647921  2.624368
# 4   -0.892428 -1.836029  0.319754    0.841774 -0.647921  2.624368
#
#    shipping_cost  expenses      year  ship-mode_Same Day  \
# 0       0.152981 -0.028289 -1.546987           -0.235763
# 1      -2.185191 -1.593530 -0.676820           -0.235763
# 2      -2.040173 -1.231581 -0.676820           -0.235763
# 3      -1.588657 -2.599843 -0.676820           -0.235763
# 4      -1.785354 -0.857603 -0.676820           -0.235763
#
#    ship-mode_Second Class  ship-mode_Standard Class  seg_Home Office  \
# 0               -0.501615                  0.816463         2.119060
# 1               -0.501615                  0.816463        -0.471907
# 2               -0.501615                  0.816463         2.119060
# 3               -0.501615                  0.816463        -0.471907
# 4               -0.501615                  0.816463        -0.471907
#
#    mar_APAC  mar_Africa  mar_Canada  mar_EMEA    mar_EU  mar_LATAM    mar_US  \
# 0 -0.522551    3.190732   -0.086865 -0.329728 -0.492033  -0.501127 -0.491972
# 1 -0.522551    3.190732   -0.086865 -0.329728 -0.492033  -0.501127 -0.491972
# 2 -0.522551    3.190732   -0.086865 -0.329728 -0.492033  -0.501127 -0.491972
# 3 -0.522551    3.190732   -0.086865 -0.329728 -0.492033  -0.501127 -0.491972
# 4 -0.522551    3.190732   -0.086865 -0.329728 -0.492033  -0.501127 -0.491972
#
#    reg_Caribbean  reg_Central  reg_Central Asia  reg_East  reg_North  \
# 0      -0.184672    -0.525967         -0.203865 -0.242463  -0.320746
# 1      -0.184672    -0.525967         -0.203865 -0.242463  -0.320746
# 2      -0.184672    -0.525967         -0.203865 -0.242463  -0.320746
# 3      -0.184672    -0.525967         -0.203865 -0.242463  -0.320746
# 4      -0.184672    -0.525967         -0.203865 -0.242463  -0.320746
#
#    reg_North Asia  reg_Oceania  reg_South  reg_Southeast Asia  reg_West  \
# 0       -0.218577    -0.270085  -0.385864           -0.254888 -0.258083
# 1       -0.218577    -0.270085  -0.385864           -0.254888 -0.258083
# 2       -0.218577    -0.270085  -0.385864           -0.254888 -0.258083
# 3       -0.218577    -0.270085  -0.385864           -0.254888 -0.258083
# 4       -0.218577    -0.270085  -0.385864           -0.254888 -0.258083
#
#    cat_OFFICE SUPPLIES  cat_TECHNOLOGY  sub_cat_APPLIANCES  sub_cat_ART  \
# 0             0.800008       -0.496402           -0.188256     3.082672
# 1             0.800008       -0.496402           -0.188256    -0.324394
# 2             0.800008       -0.496402           -0.188256    -0.324394
# 3             0.800008       -0.496402           -0.188256    -0.324394
# 4             0.800008       -0.496402           -0.188256     3.082672
#
#    sub_cat_BINDERS  sub_cat_BOOKCASES  sub_cat_CHAIRS  sub_cat_COPIERS  \
# 0        -0.369138           -0.22208       -0.267917        -0.212833
# 1        -0.369138           -0.22208       -0.267917        -0.212833
# 2        -0.369138           -0.22208       -0.267917        -0.212833
# 3        -0.369138           -0.22208       -0.267917        -0.212833
# 4        -0.369138           -0.22208       -0.267917        -0.212833
#
#    sub_cat_ENVELOPES  sub_cat_FASTENERS  sub_cat_FURNISHINGS  sub_cat_LABELS  \
# 0          -0.223334          -0.222515            -0.256662       -0.231399
# 1          -0.223334          -0.222515            -0.256662       -0.231399
# 2          -0.223334          -0.222515            -0.256662       -0.231399
# 3          -0.223334          -0.222515            -0.256662       -0.231399
# 4          -0.223334          -0.222515            -0.256662       -0.231399
#
#    sub_cat_MACHINES  sub_cat_PAPER  sub_cat_PHONES  sub_cat_STORAGE  \
# 0          -0.17276       -0.27224       -0.264599        -0.330745
# 1          -0.17276       -0.27224       -0.264599        -0.330745
# 2          -0.17276       -0.27224       -0.264599         3.023477
# 3          -0.17276       -0.27224       -0.264599         3.023477
# 4          -0.17276       -0.27224       -0.264599        -0.330745
#
#    sub_cat_SUPPLIES  sub_cat_TABLES  ord_High   ord_Low  ord_Medium
# 0         -0.222756       -0.130608 -0.658228 -0.222708    0.861826
# 1          4.489215       -0.130608 -0.658228 -0.222708    0.861826
# 2         -0.222756       -0.130608 -0.658228 -0.222708    0.861826
# 3         -0.222756       -0.130608 -0.658228 -0.222708    0.861826
# 4         -0.222756       -0.130608 -0.658228 -0.222708    0.861826

# %%
y.head()
# Out:
#                      sales
# order_id
# ES-2011-1630549  15.376721
# MX-2013-132906    9.648513
# MX-2013-113579   10.986060
# CA-2013-116337    5.887143
# ES-2013-4232414  12.369943

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.1,random_state = 7)

# %% [markdown]
# <a name = "Model"></a>
# ## 8.Model training

# %% [markdown]
# #### XGBoost Regressor Model

# %%
xgb = XGBRegressor()
xgb.fit(x_train, y_train)
y_pred = xgb.predict(x_test)

# %%
print('Score R-squared: {}'.format(xgb.score(x_test,y_test)*100),"%")
# Out:
# Accuracy: 99.92976039866134 %

# %%
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print('Mean Absolute Error:', mae)
print('Root Mean Squared Error:', rmse)
# Out:
# Mean Absolute Error: 0.04516180172088965
# Root Mean Squared Error: 0.07860470787466131

# %% [markdown]
# <a name = "Predictions"></a>
# ## 9.Test set predictions

# %% [markdown]
# ### Feature Importances

# %%
print(xgb.feature_importances_)
# Out:
# [2.60165198e-05 8.71201482e-05 1.17343297e-04 5.18792421e-02
#  3.22882757e-02 1.07632853e-01 1.07325027e-02 7.88632870e-01
#  6.11525466e-05 8.74675534e-05 1.17980708e-04 6.76734562e-05
#  7.14338385e-05 1.18580705e-04 6.68424182e-05 8.09068638e-07
#  1.26674597e-04 1.32923975e-04 1.80125746e-04 2.35526008e-04
#  8.40280154e-06 4.02954826e-03 1.32548288e-04 8.05315503e-05
#  1.26505445e-04 8.31415164e-05 1.27371604e-04 2.88979587e-04
#  1.85639787e-04 8.57449704e-05 2.25374009e-04 2.65973154e-04
#  1.40408607e-04 2.74511658e-05 7.70373299e-05 1.35337294e-04
#  7.61213814e-05 1.13667826e-04 7.89504775e-05 1.52838358e-04
#  1.01371603e-04 1.44303558e-05 9.56788572e-05 1.02298778e-04
#  1.00913741e-04 8.12238140e-05 2.75197690e-05 1.17918986e-04
#  1.00203193e-04 1.03441096e-04 5.00222195e-05]

# %%
importance_scores = xgb.feature_importances_
feature_names = x_train.columns

# Create a dictionary of feature names and their importance scores
feature_importances = dict(zip(feature_names, importance_scores))

# Sort the dictionary by importance scores in descending order
sorted_feature_importances = sorted(feature_importances.items(), key=lambda x: x[1], reverse=True)

# Extract the feature names and their importance scores
features, scores = zip(*sorted_feature_importances)

# Plot the feature importance scores as a bar chart
plt.figure(figsize=(20,10))
plt.bar(features, scores)
plt.xticks(rotation=90)
plt.xlabel("Features", fontdict={'fontsize':12})
plt.ylabel("Importance Scores", fontdict={'fontsize':12})
plt.title("Feature Importance Scores", fontdict={'fontsize':18}, pad=12)
plt.show()

# %%
cmap = plt.cm.get_cmap('tab20c_r')
colors = [cmap(i) for i in range(x.shape[1])]
fig, ax = plt.subplots(figsize=(20, 15))
plot_importance(xgb, ax=ax, color=colors)
plt.title('Feature Importances', fontdict={'fontsize':18}, pad=12)
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()

# %%
# Get feature importance scores and sort in descending order
importance_scores = xgb.feature_importances_
feature_names = x_train.columns
feature_importances = list(zip(feature_names, importance_scores))
feature_importances_sorted = sorted(feature_importances, key=lambda x: x[1], reverse=True)

# Print feature importance scores
print("Feature Importances:")
for feature, importance in feature_importances_sorted:
    print(feature, ": ", importance)

# Set a threshold for selecting important features
threshold = 0.01

# Identify non-important features
non_important_features = [feature for feature, importance in feature_importances_sorted if importance < threshold]
print("Non-important Features:", non_important_features)

# Drop non-important features from the training and testing sets
x_train_dropped = x_train.drop(non_important_features, axis=1)
x_test_dropped = x_test.drop(non_important_features, axis=1)
# Out:
# Feature Importances:
# expenses :  0.78863287
# discount :  0.10763285
# Unit Price :  0.051879242
# quantity :  0.032288276
# shipping_cost :  0.010732503
# reg_Central :  0.0040295483
# reg_South :  0.0002889796
# cat_TECHNOLOGY :  0.00026597315
# mar_US :  0.00023552601
# cat_OFFICE SUPPLIES :  0.00022537401
# reg_Southeast Asia :  0.00018563979
# mar_LATAM :  0.00018012575
# sub_cat_FASTENERS :  0.00015283836
# sub_cat_APPLIANCES :  0.0001404086
# sub_cat_BOOKCASES :  0.0001353373
# mar_EU :  0.00013292397
# reg_Central Asia :  0.00013254829
# reg_Oceania :  0.0001273716
# mar_EMEA :  0.0001266746
# reg_North :  0.00012650545
# mar_APAC :  0.000118580705
# ship-mode_Second Class :  0.00011798071
# sub_cat_TABLES :  0.000117918986
# country :  0.0001173433
# sub_cat_COPIERS :  0.000113667826
# ord_Low :  0.000103441096
# sub_cat_PAPER :  0.00010229878
# sub_cat_FURNISHINGS :  0.0001013716
# sub_cat_PHONES :  0.00010091374
# ord_High :  0.00010020319
# sub_cat_MACHINES :  9.567886e-05
# ship-mode_Same Day :  8.746755e-05
# state :  8.712015e-05
# reg_West :  8.574497e-05
# reg_North Asia :  8.314152e-05
# sub_cat_STORAGE :  8.1223814e-05
# reg_East :  8.053155e-05
# sub_cat_ENVELOPES :  7.895048e-05
# sub_cat_BINDERS :  7.703733e-05
# sub_cat_CHAIRS :  7.612138e-05
# seg_Home Office :  7.143384e-05
# ship-mode_Standard Class :  6.7673456e-05
# mar_Africa :  6.684242e-05
# year :  6.115255e-05
# ord_Medium :  5.002222e-05
# sub_cat_SUPPLIES :  2.7519769e-05
# sub_cat_ART :  2.7451166e-05
# id_segment :  2.601652e-05
# sub_cat_LABELS :  1.4430356e-05
# reg_Caribbean :  8.4028015e-06
# mar_Canada :  8.0906864e-07
# Non-important Features: ['reg_Central', 'reg_South', 'cat_TECHNOLOGY', 'mar_US', 'cat_OFFICE SUPPLIES', 'reg_Southeast Asia', 'mar_LATAM', 'sub_cat_FASTENERS', 'sub_cat_APPLIANCES', 'sub_cat_BOOKCASES', 'mar_EU', 'reg_Central Asia', 'reg_Oceania', 'mar_EMEA', 'reg_North', 'mar_APAC', 'ship-mode_Second Class', 'sub_cat_TABLES', 'country', 'sub_cat_COPIERS', 'ord_Low', 'sub_cat_PAPER', 'sub_cat_FURNISHINGS', 'sub_cat_PHONES', 'ord_High', 'sub_cat_MACHINES', 'ship-mode_Same Day', 'state', 'reg_West', 'reg_North Asia', 'sub_cat_STORAGE', 'reg_East', 'sub_cat_ENVELOPES', 'sub_cat_BINDERS', 'sub_cat_CHAIRS', 'seg_Home Office', 'ship-mode_Standard Class', 'mar_Africa', 'year', 'ord_Medium', 'sub_cat_SUPPLIES', 'sub_cat_ART', 'id_segment', 'sub_cat_LABELS', 'reg_Caribbean', 'mar_Canada']

# %%
x_train_dropped.head()
# Out:
#        Unit Price  quantity  discount  shipping_cost  expenses
# 32903   -0.639220 -0.647921  0.268947      -1.163996 -0.682205
# 45087    0.414107  0.668624 -0.673222       0.515959  1.162003
# 39631    0.469545 -0.647921 -0.673222      -0.844344  0.147584
# 13434    0.620021  1.107472 -0.673222      -0.641205  1.481119
# 46197   -1.716307 -0.209072  0.268947       1.023548 -1.516042

# %%
y_train
# Out:
#                      sales
# order_id
# US-2014-108700   10.023694
# ES-2011-1878479  14.925547
# SF-2013-1320     11.905187
# MX-2012-164378   15.931140
# NI-2014-3940      6.131089
# ...                    ...
# MX-2014-162257    9.225257
# ES-2011-4864498  12.622511
# CA-2014-141614   13.013338
# IN-2014-34639    16.098250
# NI-2013-3270     10.296503
#
# [46147 rows x 1 columns]

# %%
# Train a new XGBRegressor model with the dropped features
xgb_dropped = XGBRegressor()
xgb_dropped.fit(x_train_dropped, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
# Evaluate the new model on the testing set
y_pred_dropped = xgb_dropped.predict(x_test_dropped)
mae_dropped = mean_absolute_error(y_test, y_pred_dropped)
rmse_dropped = mean_squared_error(y_test, y_pred_dropped, squared=False)

print('Mean Absolute Error (dropped features):', mae_dropped)
print('Root Mean Squared Error (dropped features):', rmse_dropped)
# Out:
# Mean Absolute Error (dropped features): 0.044580659349926395
# Root Mean Squared Error (dropped features): 0.07735417768549063

# %%
print('Score R-squared: {}'.format(xgb_dropped.score(x_test_dropped,y_test)*100),"%")
# Out:
# Accuracy: 99.93197751879403 %

# %% [markdown]
# ## GridSearchCV

# %%
param_grid = {
    'learning_rate': [0.01, 0.1, 0.3],
    'max_depth': [3, 5, 7],
    'n_estimators': [50, 100, 1000]
}

# %%
clf = GridSearchCV(estimator=xgb, param_grid=param_grid, cv=5,verbose=2)

clf.fit(x_train_dropped, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END .learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   4.8s
# [CV] END .learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   4.8s
# [CV] END .learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   4.8s
# [CV] END .learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   4.8s
# [CV] END .learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   4.9s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END .learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   8.4s
# [CV] END .learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   8.4s
# [CV] END .learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   8.6s
# [CV] END .learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   8.6s
# [CV] END .learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   8.9s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   0.5s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   1.4s
# [CV] END .learning_rate=0.01, max_depth=7, n_estimators=1000; total time=  15.1s
# [CV] END .learning_rate=0.01, max_depth=7, n_estimators=1000; total time=  14.2s
# [CV] END .learning_rate=0.01, max_depth=7, n_estimators=1000; total time=  12.5s
# [CV] END .learning_rate=0.01, max_depth=7, n_estimators=1000; total time=  12.4s
# [CV] END .learning_rate=0.01, max_depth=7, n_estimators=1000; total time=  12.4s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   5.1s
# [CV] END ..learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   5.1s
# [CV] END ..learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   5.1s
# [CV] END ..learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   5.1s
# [CV] END ..learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   5.2s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.5s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   1.0s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   1.0s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.8s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.9s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   1.0s
# [CV] END ..learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   9.6s
# [CV] END ..learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   9.5s
# [CV] END ..learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   9.2s
# [CV] END ..learning_rate=0.1, max_depth=5, n_estimators=1000; total time=  10.3s
# [CV] END ..learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   9.5s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.5s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   1.6s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   1.5s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   1.6s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   1.5s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.1, max_depth=7, n_estimators=1000; total time=  13.1s
# [CV] END ..learning_rate=0.1, max_depth=7, n_estimators=1000; total time=  12.9s
# [CV] END ..learning_rate=0.1, max_depth=7, n_estimators=1000; total time=  13.0s
# [CV] END ..learning_rate=0.1, max_depth=7, n_estimators=1000; total time=  13.3s
# [CV] END ..learning_rate=0.1, max_depth=7, n_estimators=1000; total time=  12.3s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=100; total time=   0.5s
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=100; total time=   0.5s
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=100; total time=   0.5s
# [CV] END ..learning_rate=0.3, max_depth=3, n_estimators=1000; total time=   5.3s
# [CV] END ..learning_rate=0.3, max_depth=3, n_estimators=1000; total time=   5.3s
# [CV] END ..learning_rate=0.3, max_depth=3, n_estimators=1000; total time=   5.4s
# [CV] END ..learning_rate=0.3, max_depth=3, n_estimators=1000; total time=   5.2s
# [CV] END ..learning_rate=0.3, max_depth=3, n_estimators=1000; total time=   5.3s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.4s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.4s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.4s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.4s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.4s
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=100; total time=   0.9s
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=100; total time=   0.9s
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=100; total time=   0.9s
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=100; total time=   0.9s
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=100; total time=   0.9s
# [CV] END ..learning_rate=0.3, max_depth=5, n_estimators=1000; total time=   9.0s
# [CV] END ..learning_rate=0.3, max_depth=5, n_estimators=1000; total time=   8.8s
# [CV] END ..learning_rate=0.3, max_depth=5, n_estimators=1000; total time=   8.9s
# [CV] END ..learning_rate=0.3, max_depth=5, n_estimators=1000; total time=   8.8s
# [CV] END ..learning_rate=0.3, max_depth=5, n_estimators=1000; total time=   8.9s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.6s
# [CV] END ...learning_rate=0.3, max_depth=7, n_estimators=100; total time=   1.2s
# [CV] END ...learning_rate=0.3, max_depth=7, n_estimators=100; total time=   1.2s
# [CV] END ...learning_rate=0.3, max_depth=7, n_estimators=100; total time=   1.2s
# [CV] END ...learning_rate=0.3, max_depth=7, n_estimators=100; total time=   1.2s
# [CV] END ...learning_rate=0.3, max_depth=7, n_estimators=100; total time=   1.2s
# [CV] END ..learning_rate=0.3, max_depth=7, n_estimators=1000; total time=  12.6s
# [CV] END ..learning_rate=0.3, max_depth=7, n_estimators=1000; total time=  12.6s
# [CV] END ..learning_rate=0.3, max_depth=7, n_estimators=1000; total time=  12.5s
# [CV] END ..learning_rate=0.3, max_depth=7, n_estimators=1000; total time=  12.6s
# [CV] END ..learning_rate=0.3, max_depth=7, n_estimators=1000; total time=  12.6s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None, ...),
#              param_grid={'learning_rate': [0.01, 0.1, 0.3],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [50, 100, 1000]},
#              verbose=2)

# %%
print('Best parameters:', clf.best_params_)
# Out:
# Best parameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 1000}

# %%
y_pred = clf.predict(x_test_dropped)

# %%
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print('Mean Absolute Error:', mae)
print('Root Mean Squared Error:', rmse)
# Out:
# Mean Absolute Error: 0.02282889309948217
# Root Mean Squared Error: 0.040620081627439075

# %%
print('Score R-squared: {}'.format(clf.score(x_test_dropped,y_test)*100),"%")
# Out:
# Accuracy: 99.98124286494206 %

# %%
y_train_dp=y_train

# %% [markdown]
# ## Cross Validation

# %%
from ipywidgets import IntProgress
from IPython.display import display
import time

xgb = XGBRegressor(**clf.best_params_)

from contextlib import contextmanager
import warnings

@contextmanager
def suppress_warnings():
    warnings.filterwarnings('ignore')
    yield
    warnings.resetwarnings()

with suppress_warnings():
    mae_scores = []
    rmse_scores = []
    progress = IntProgress(min=0, max=5)
    display(progress)
    for i, (train_index, test_index) in enumerate(KFold(n_splits=5, shuffle=True, random_state=7).split(x)):
        x_train, x_test = x.iloc[train_index], x.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        xgb.fit(x_train, y_train)
        
        y_pred = xgb.predict(x_test)
        
        mae_scores.append(mean_absolute_error(y_test, y_pred))
        rmse_scores.append(np.sqrt(mean_squared_error(y_test, y_pred)))
        
        progress.value = i+1
        time.sleep(1)
    
    print("MAE scores: ", mae_scores)
    print("RMSE scores: ", rmse_scores)
# Out:
# IntProgress(value=0, max=5)
# MAE scores:  [0.02471271386855689, 0.024069288773357914, 0.024735173865298166, 0.02534053709151284, 0.024614920424201797]
# RMSE scores:  [0.043505688281860834, 0.04737609923293959, 0.04480427814832621, 0.049833669127772984, 0.048602059009959585]

# %%
print('Mean MAE:', np.mean(mae_scores))
print('Standard deviation of MAE:',np.std(mae_scores))
# Out:
# Mean MAE: 0.02469452680458552
# Standard deviation of MAE: 0.0004041217675769431

# %%
print("Mean RMSE:", np.mean(rmse_scores))
print('Standard deviation of RMSE:', np.std(rmse_scores))
# Out:
# Mean RMSE: 0.04682435876017184
# Standard deviation of RMSE: 0.002350101446231832

# %%
print('Score R-squared: {}'.format(xgb.score(x_test,y_test)*100),"%")
# Out:
# Accuracy: 99.97325920698195 %
